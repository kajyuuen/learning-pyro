# %%
import math
import os
import torch
import torch.distributions.constraints as constraints
import pyro
from pyro.optim import Adam
from pyro.distributions.testing.fakes import NonreparameterizedBeta
from pyro.infer import SVI, TraceGraph_ELBO
import pyro.distributions as dist
import sys

# %% [markdown]
# **モデル**
#
# ベルヌーイ分布について考える。
#
# $$
# p(x|f) = {\rm Bern}(x|f)
# $$
#
# 事前分布にはBeta分布を用いる.
#
# $$
# p(f)= {\rm Beta}(f| \alpha_0, \beta_0)
# $$
#
# **ガイド**
#
# 事後分布は
#
# $$
# p(f|{\bf X})= {\rm Beta}(f| \alpha_q, \beta_q)
# $$

# %%
def param_abs_error(name, target):
    return torch.sum(torch.abs(target - pyro.param(name))).item()

class BernoulliBetaExample:
    def __init__(self, data, max_steps):
        self.max_steps = max_steps
        # モデルの事前分布: ベータ分布のパラメータの初期値
        self.alpha0 = 10.0
        self.beta0 = 10.0

        # サイコロのデータ
        self.data = data
        self.n_data = self.data.size(0)
        
        # ガイド(事後分布): ベータ分布のパラメータの初期値
        self.alpha_q_0 = 15.0
        self.beta_q_0 = 15.0

        # 真の事後分布のパラメータを計算する
        self.alpha_n = self.data.sum() + self.alpha0
        self.beta_n = - self.data.sum() + torch.tensor(self.beta0 + self.n_data)

    def model(self, use_decaying_avg_baseline):
        f = pyro.sample("latent_fairness", dist.Beta(self.alpha0, self.beta0))
        with pyro.plate("data_plate"):
            pyro.sample("obs", dist.Bernoulli(f), obs=self.data)

    def guide(self, use_decaying_avg_baseline):
        alpha_q = pyro.param("alpha_q", torch.tensor(self.alpha_q_0), constraint=constraints.positive)
        beta_q = pyro.param("beta_q", torch.tensor(self.beta_q_0), constraint=constraints.positive)

        baseline_dict = {
            'use_decaying_avg_baseline': use_decaying_avg_baseline,
            'baseline_beta': 0.90
        }
        
        pyro.sample("latent_fairness", 
                    NonreparameterizedBeta(alpha_q, beta_q),
                    infer=dict(baseline=baseline_dict))

    def do_inference(self, use_decaying_avg_baseline, tolerance=0.80):
        pyro.clear_param_store()
        
        # optimizerと推論手法
        optimizer = Adam({"lr": .0005, "betas": (0.93, 0.999)})
        svi = SVI(self.model, self.guide, optimizer, loss=TraceGraph_ELBO())

        print("Doing inference with use_decaying_avg_baseline=%s" % use_decaying_avg_baseline)

        # Maxstepまで学習
        for k in range(self.max_steps):
            svi.step(use_decaying_avg_baseline)
            if k % 100 == 0:
                print('.', end='')
                sys.stdout.flush()

            # compute the distance to the parameters of the true posterior
            alpha_error = param_abs_error("alpha_q", self.alpha_n)
            beta_error = param_abs_error("beta_q", self.beta_n)

            # stop inference early if we're close to the true posterior
            if alpha_error < tolerance and beta_error < tolerance:
                break

            print("\nDid %d steps of inference." % k)
            print(("Final absolute errors for the two variational parameters " + "were %.4f & %.4f") % (alpha_error, beta_error))

# %%
data = torch.zeros(10)
data[:6] = torch.ones(6)

# %%
bbe = BernoulliBetaExample(data, max_steps=10000)
bbe.do_inference(use_decaying_avg_baseline=True)
bbe.do_inference(use_decaying_avg_baseline=False)
# Out:
# Doing inference with use_decaying_avg_baseline=True
# .
# Did 0 steps of inference.
# Final absolute errors for the two variational parameters were 1.0075 & 0.9925
#
# Did 1 steps of inference.
# Final absolute errors for the two variational parameters were 1.0138 & 0.9976
#
# Did 2 steps of inference.
# Final absolute errors for the two variational parameters were 1.0202 & 1.0028
#
# Did 3 steps of inference.
# Final absolute errors for the two variational parameters were 1.0189 & 1.0013
#
# Did 4 steps of inference.
# Final absolute errors for the two variational parameters were 1.0174 & 0.9994
#
# Did 5 steps of inference.
# Final absolute errors for the two variational parameters were 1.0162 & 0.9976
#
# Did 6 steps of inference.
# Final absolute errors for the two variational parameters were 1.0157 & 0.9965
#
# Did 7 steps of inference.
# Final absolute errors for the two variational parameters were 1.0140 & 0.9942
#
# Did 8 steps of inference.
# Final absolute errors for the two variational parameters were 1.0130 & 0.9926
#
# Did 9 steps of inference.
# Final absolute errors for the two variational parameters were 1.0124 & 0.9917
#
# Did 10 steps of inference.
# Final absolute errors for the two variational parameters were 1.0125 & 0.9915
#
# Did 11 steps of inference.
# Final absolute errors for the two variational parameters were 1.0117 & 0.9904
#
# Did 12 steps of inference.
# Final absolute errors for the two variational parameters were 1.0098 & 0.9885
#
# Did 13 steps of inference.
# Final absolute errors for the two variational parameters were 1.0081 & 0.9865
#
# Did 14 steps of inference.
# Final absolute errors for the two variational parameters were 1.0058 & 0.9841
#
# Did 15 steps of inference.
# Final absolute errors for the two variational parameters were 1.0037 & 0.9818
#
# Did 16 steps of inference.
# Final absolute errors for the two variational parameters were 1.0014 & 0.9793
#
# Did 17 steps of inference.
# Final absolute errors for the two variational parameters were 0.9990 & 0.9766
#
# Did 18 steps of inference.
# Final absolute errors for the two variational parameters were 0.9967 & 0.9742
#
# Did 19 steps of inference.
# Final absolute errors for the two variational parameters were 0.9948 & 0.9720
#
# Did 20 steps of inference.
# Final absolute errors for the two variational parameters were 0.9930 & 0.9701
#
# Did 21 steps of inference.
# Final absolute errors for the two variational parameters were 0.9911 & 0.9681
#
# Did 22 steps of inference.
# Final absolute errors for the two variational parameters were 0.9890 & 0.9658
#
# Did 23 steps of inference.
# Final absolute errors for the two variational parameters were 0.9870 & 0.9637
#
# Did 24 steps of inference.
# Final absolute errors for the two variational parameters were 0.9851 & 0.9617
#
# Did 25 steps of inference.
# Final absolute errors for the two variational parameters were 0.9833 & 0.9597
#
# Did 26 steps of inference.
# Final absolute errors for the two variational parameters were 0.9815 & 0.9578
#
# Did 27 steps of inference.
# Final absolute errors for the two variational parameters were 0.9799 & 0.9560
#
# Did 28 steps of inference.
# Final absolute errors for the two variational parameters were 0.9782 & 0.9541
#
# Did 29 steps of inference.
# Final absolute errors for the two variational parameters were 0.9765 & 0.9521
#
# Did 30 steps of inference.
# Final absolute errors for the two variational parameters were 0.9745 & 0.9500
#
# Did 31 steps of inference.
# Final absolute errors for the two variational parameters were 0.9728 & 0.9480
#
# Did 32 steps of inference.
# Final absolute errors for the two variational parameters were 0.9711 & 0.9462
#
# Did 33 steps of inference.
# Final absolute errors for the two variational parameters were 0.9695 & 0.9444
#
# Did 34 steps of inference.
# Final absolute errors for the two variational parameters were 0.9680 & 0.9428
#
# Did 35 steps of inference.
# Final absolute errors for the two variational parameters were 0.9665 & 0.9411
#
# Did 36 steps of inference.
# Final absolute errors for the two variational parameters were 0.9652 & 0.9396
#
# Did 37 steps of inference.
# Final absolute errors for the two variational parameters were 0.9637 & 0.9379
#
# Did 38 steps of inference.
# Final absolute errors for the two variational parameters were 0.9623 & 0.9364
#
# Did 39 steps of inference.
# Final absolute errors for the two variational parameters were 0.9610 & 0.9349
#
# Did 40 steps of inference.
# Final absolute errors for the two variational parameters were 0.9597 & 0.9335
#
# Did 41 steps of inference.
# Final absolute errors for the two variational parameters were 0.9586 & 0.9322
#
# Did 42 steps of inference.
# Final absolute errors for the two variational parameters were 0.9574 & 0.9308
#
# Did 43 steps of inference.
# Final absolute errors for the two variational parameters were 0.9562 & 0.9295
#
# Did 44 steps of inference.
# Final absolute errors for the two variational parameters were 0.9551 & 0.9283
#
# Did 45 steps of inference.
# Final absolute errors for the two variational parameters were 0.9540 & 0.9271
#
# Did 46 steps of inference.
# Final absolute errors for the two variational parameters were 0.9529 & 0.9258
#
# Did 47 steps of inference.
# Final absolute errors for the two variational parameters were 0.9518 & 0.9245
#
# Did 48 steps of inference.
# Final absolute errors for the two variational parameters were 0.9506 & 0.9231
#
# Did 49 steps of inference.
# Final absolute errors for the two variational parameters were 0.9494 & 0.9216
#
# Did 50 steps of inference.
# Final absolute errors for the two variational parameters were 0.9482 & 0.9202
#
# Did 51 steps of inference.
# Final absolute errors for the two variational parameters were 0.9470 & 0.9188
#
# Did 52 steps of inference.
# Final absolute errors for the two variational parameters were 0.9458 & 0.9174
#
# Did 53 steps of inference.
# Final absolute errors for the two variational parameters were 0.9447 & 0.9160
#
# Did 54 steps of inference.
# Final absolute errors for the two variational parameters were 0.9433 & 0.9143
#
# Did 55 steps of inference.
# Final absolute errors for the two variational parameters were 0.9418 & 0.9124
#
# Did 56 steps of inference.
# Final absolute errors for the two variational parameters were 0.9404 & 0.9106
#
# Did 57 steps of inference.
# Final absolute errors for the two variational parameters were 0.9391 & 0.9089
#
# Did 58 steps of inference.
# Final absolute errors for the two variational parameters were 0.9379 & 0.9073
#
# Did 59 steps of inference.
# Final absolute errors for the two variational parameters were 0.9367 & 0.9058
#
# Did 60 steps of inference.
# Final absolute errors for the two variational parameters were 0.9356 & 0.9044
#
# Did 61 steps of inference.
# Final absolute errors for the two variational parameters were 0.9345 & 0.9030
#
# Did 62 steps of inference.
# Final absolute errors for the two variational parameters were 0.9334 & 0.9015
#
# Did 63 steps of inference.
# Final absolute errors for the two variational parameters were 0.9321 & 0.9000
#
# Did 64 steps of inference.
# Final absolute errors for the two variational parameters were 0.9309 & 0.8984
#
# Did 65 steps of inference.
# Final absolute errors for the two variational parameters were 0.9297 & 0.8970
#
# Did 66 steps of inference.
# Final absolute errors for the two variational parameters were 0.9286 & 0.8956
#
# Did 67 steps of inference.
# Final absolute errors for the two variational parameters were 0.9275 & 0.8942
#
# Did 68 steps of inference.
# Final absolute errors for the two variational parameters were 0.9265 & 0.8930
#
# Did 69 steps of inference.
# Final absolute errors for the two variational parameters were 0.9255 & 0.8917
#
# Did 70 steps of inference.
# Final absolute errors for the two variational parameters were 0.9245 & 0.8905
#
# Did 71 steps of inference.
# Final absolute errors for the two variational parameters were 0.9235 & 0.8893
#
# Did 72 steps of inference.
# Final absolute errors for the two variational parameters were 0.9225 & 0.8881
#
# Did 73 steps of inference.
# Final absolute errors for the two variational parameters were 0.9215 & 0.8869
#
# Did 74 steps of inference.
# Final absolute errors for the two variational parameters were 0.9205 & 0.8857
#
# Did 75 steps of inference.
# Final absolute errors for the two variational parameters were 0.9193 & 0.8843
#
# Did 76 steps of inference.
# Final absolute errors for the two variational parameters were 0.9180 & 0.8827
#
# Did 77 steps of inference.
# Final absolute errors for the two variational parameters were 0.9168 & 0.8811
#
# Did 78 steps of inference.
# Final absolute errors for the two variational parameters were 0.9156 & 0.8796
#
# Did 79 steps of inference.
# Final absolute errors for the two variational parameters were 0.9141 & 0.8780
#
# Did 80 steps of inference.
# Final absolute errors for the two variational parameters were 0.9128 & 0.8764
#
# Did 81 steps of inference.
# Final absolute errors for the two variational parameters were 0.9114 & 0.8748
#
# Did 82 steps of inference.
# Final absolute errors for the two variational parameters were 0.9101 & 0.8733
#
# Did 83 steps of inference.
# Final absolute errors for the two variational parameters were 0.9089 & 0.8719
#
# Did 84 steps of inference.
# Final absolute errors for the two variational parameters were 0.9076 & 0.8704
#
# Did 85 steps of inference.
# Final absolute errors for the two variational parameters were 0.9064 & 0.8690
#
# Did 86 steps of inference.
# Final absolute errors for the two variational parameters were 0.9052 & 0.8676
#
# Did 87 steps of inference.
# Final absolute errors for the two variational parameters were 0.9040 & 0.8662
#
# Did 88 steps of inference.
# Final absolute errors for the two variational parameters were 0.9030 & 0.8650
#
# Did 89 steps of inference.
# Final absolute errors for the two variational parameters were 0.9019 & 0.8638
#
# Did 90 steps of inference.
# Final absolute errors for the two variational parameters were 0.9010 & 0.8627
#
# Did 91 steps of inference.
# Final absolute errors for the two variational parameters were 0.9001 & 0.8616
#
# Did 92 steps of inference.
# Final absolute errors for the two variational parameters were 0.8992 & 0.8605
#
# Did 93 steps of inference.
# Final absolute errors for the two variational parameters were 0.8983 & 0.8595
#
# Did 94 steps of inference.
# Final absolute errors for the two variational parameters were 0.8974 & 0.8585
#
# Did 95 steps of inference.
# Final absolute errors for the two variational parameters were 0.8965 & 0.8575
#
# Did 96 steps of inference.
# Final absolute errors for the two variational parameters were 0.8956 & 0.8565
#
# Did 97 steps of inference.
# Final absolute errors for the two variational parameters were 0.8948 & 0.8555
#
# Did 98 steps of inference.
# Final absolute errors for the two variational parameters were 0.8938 & 0.8543
#
# Did 99 steps of inference.
# Final absolute errors for the two variational parameters were 0.8927 & 0.8530
# .
# Did 100 steps of inference.
# Final absolute errors for the two variational parameters were 0.8909 & 0.8513
#
# Did 101 steps of inference.
# Final absolute errors for the two variational parameters were 0.8892 & 0.8495
#
# Did 102 steps of inference.
# Final absolute errors for the two variational parameters were 0.8875 & 0.8479
#
# Did 103 steps of inference.
# Final absolute errors for the two variational parameters were 0.8860 & 0.8464
#
# Did 104 steps of inference.
# Final absolute errors for the two variational parameters were 0.8838 & 0.8436
#
# Did 105 steps of inference.
# Final absolute errors for the two variational parameters were 0.8817 & 0.8409
#
# Did 106 steps of inference.
# Final absolute errors for the two variational parameters were 0.8797 & 0.8383
#
# Did 107 steps of inference.
# Final absolute errors for the two variational parameters were 0.8778 & 0.8359
#
# Did 108 steps of inference.
# Final absolute errors for the two variational parameters were 0.8758 & 0.8335
#
# Did 109 steps of inference.
# Final absolute errors for the two variational parameters were 0.8741 & 0.8313
#
# Did 110 steps of inference.
# Final absolute errors for the two variational parameters were 0.8722 & 0.8290
#
# Did 111 steps of inference.
# Final absolute errors for the two variational parameters were 0.8703 & 0.8267
#
# Did 112 steps of inference.
# Final absolute errors for the two variational parameters were 0.8686 & 0.8246
#
# Did 113 steps of inference.
# Final absolute errors for the two variational parameters were 0.8669 & 0.8226
#
# Did 114 steps of inference.
# Final absolute errors for the two variational parameters were 0.8654 & 0.8207
#
# Did 115 steps of inference.
# Final absolute errors for the two variational parameters were 0.8638 & 0.8188
#
# Did 116 steps of inference.
# Final absolute errors for the two variational parameters were 0.8621 & 0.8168
#
# Did 117 steps of inference.
# Final absolute errors for the two variational parameters were 0.8602 & 0.8147
#
# Did 118 steps of inference.
# Final absolute errors for the two variational parameters were 0.8583 & 0.8125
#
# Did 119 steps of inference.
# Final absolute errors for the two variational parameters were 0.8565 & 0.8105
#
# Did 120 steps of inference.
# Final absolute errors for the two variational parameters were 0.8547 & 0.8085
#
# Did 121 steps of inference.
# Final absolute errors for the two variational parameters were 0.8528 & 0.8065
#
# Did 122 steps of inference.
# Final absolute errors for the two variational parameters were 0.8510 & 0.8045
#
# Did 123 steps of inference.
# Final absolute errors for the two variational parameters were 0.8492 & 0.8026
#
# Did 124 steps of inference.
# Final absolute errors for the two variational parameters were 0.8475 & 0.8007
#
# Did 125 steps of inference.
# Final absolute errors for the two variational parameters were 0.8459 & 0.7990
#
# Did 126 steps of inference.
# Final absolute errors for the two variational parameters were 0.8443 & 0.7973
#
# Did 127 steps of inference.
# Final absolute errors for the two variational parameters were 0.8427 & 0.7956
#
# Did 128 steps of inference.
# Final absolute errors for the two variational parameters were 0.8413 & 0.7941
#
# Did 129 steps of inference.
# Final absolute errors for the two variational parameters were 0.8399 & 0.7926
#
# Did 130 steps of inference.
# Final absolute errors for the two variational parameters were 0.8385 & 0.7911
#
# Did 131 steps of inference.
# Final absolute errors for the two variational parameters were 0.8371 & 0.7897
#
# Did 132 steps of inference.
# Final absolute errors for the two variational parameters were 0.8357 & 0.7882
#
# Did 133 steps of inference.
# Final absolute errors for the two variational parameters were 0.8343 & 0.7866
#
# Did 134 steps of inference.
# Final absolute errors for the two variational parameters were 0.8330 & 0.7852
#
# Did 135 steps of inference.
# Final absolute errors for the two variational parameters were 0.8316 & 0.7837
#
# Did 136 steps of inference.
# Final absolute errors for the two variational parameters were 0.8302 & 0.7822
#
# Did 137 steps of inference.
# Final absolute errors for the two variational parameters were 0.8289 & 0.7808
#
# Did 138 steps of inference.
# Final absolute errors for the two variational parameters were 0.8277 & 0.7795
#
# Did 139 steps of inference.
# Final absolute errors for the two variational parameters were 0.8264 & 0.7781
#
# Did 140 steps of inference.
# Final absolute errors for the two variational parameters were 0.8253 & 0.7769
#
# Did 141 steps of inference.
# Final absolute errors for the two variational parameters were 0.8241 & 0.7756
#
# Did 142 steps of inference.
# Final absolute errors for the two variational parameters were 0.8227 & 0.7741
#
# Did 143 steps of inference.
# Final absolute errors for the two variational parameters were 0.8215 & 0.7727
#
# Did 144 steps of inference.
# Final absolute errors for the two variational parameters were 0.8203 & 0.7713
#
# Did 145 steps of inference.
# Final absolute errors for the two variational parameters were 0.8191 & 0.7700
#
# Did 146 steps of inference.
# Final absolute errors for the two variational parameters were 0.8178 & 0.7685
#
# Did 147 steps of inference.
# Final absolute errors for the two variational parameters were 0.8164 & 0.7670
#
# Did 148 steps of inference.
# Final absolute errors for the two variational parameters were 0.8151 & 0.7655
#
# Did 149 steps of inference.
# Final absolute errors for the two variational parameters were 0.8139 & 0.7641
#
# Did 150 steps of inference.
# Final absolute errors for the two variational parameters were 0.8124 & 0.7622
#
# Did 151 steps of inference.
# Final absolute errors for the two variational parameters were 0.8109 & 0.7604
#
# Did 152 steps of inference.
# Final absolute errors for the two variational parameters were 0.8095 & 0.7587
#
# Did 153 steps of inference.
# Final absolute errors for the two variational parameters were 0.8083 & 0.7571
#
# Did 154 steps of inference.
# Final absolute errors for the two variational parameters were 0.8070 & 0.7556
#
# Did 155 steps of inference.
# Final absolute errors for the two variational parameters were 0.8055 & 0.7538
#
# Did 156 steps of inference.
# Final absolute errors for the two variational parameters were 0.8038 & 0.7520
#
# Did 157 steps of inference.
# Final absolute errors for the two variational parameters were 0.8022 & 0.7502
#
# Did 158 steps of inference.
# Final absolute errors for the two variational parameters were 0.8007 & 0.7485
# Doing inference with use_decaying_avg_baseline=False
# .
# Did 0 steps of inference.
# Final absolute errors for the two variational parameters were 1.0075 & 1.0075
#
# Did 1 steps of inference.
# Final absolute errors for the two variational parameters were 1.0142 & 1.0132
#
# Did 2 steps of inference.
# Final absolute errors for the two variational parameters were 1.0196 & 1.0158
#
# Did 3 steps of inference.
# Final absolute errors for the two variational parameters were 1.0257 & 1.0204
#
# Did 4 steps of inference.
# Final absolute errors for the two variational parameters were 1.0318 & 1.0251
#
# Did 5 steps of inference.
# Final absolute errors for the two variational parameters were 1.0383 & 1.0305
#
# Did 6 steps of inference.
# Final absolute errors for the two variational parameters were 1.0420 & 1.0328
#
# Did 7 steps of inference.
# Final absolute errors for the two variational parameters were 1.0461 & 1.0356
#
# Did 8 steps of inference.
# Final absolute errors for the two variational parameters were 1.0507 & 1.0388
#
# Did 9 steps of inference.
# Final absolute errors for the two variational parameters were 1.0547 & 1.0412
#
# Did 10 steps of inference.
# Final absolute errors for the two variational parameters were 1.0596 & 1.0449
#
# Did 11 steps of inference.
# Final absolute errors for the two variational parameters were 1.0630 & 1.0470
#
# Did 12 steps of inference.
# Final absolute errors for the two variational parameters were 1.0638 & 1.0470
#
# Did 13 steps of inference.
# Final absolute errors for the two variational parameters were 1.0624 & 1.0452
#
# Did 14 steps of inference.
# Final absolute errors for the two variational parameters were 1.0608 & 1.0431
#
# Did 15 steps of inference.
# Final absolute errors for the two variational parameters were 1.0595 & 1.0412
#
# Did 16 steps of inference.
# Final absolute errors for the two variational parameters were 1.0588 & 1.0399
#
# Did 17 steps of inference.
# Final absolute errors for the two variational parameters were 1.0568 & 1.0374
#
# Did 18 steps of inference.
# Final absolute errors for the two variational parameters were 1.0552 & 1.0351
#
# Did 19 steps of inference.
# Final absolute errors for the two variational parameters were 1.0531 & 1.0324
#
# Did 20 steps of inference.
# Final absolute errors for the two variational parameters were 1.0517 & 1.0303
#
# Did 21 steps of inference.
# Final absolute errors for the two variational parameters were 1.0510 & 1.0290
#
# Did 22 steps of inference.
# Final absolute errors for the two variational parameters were 1.0494 & 1.0269
#
# Did 23 steps of inference.
# Final absolute errors for the two variational parameters were 1.0484 & 1.0253
#
# Did 24 steps of inference.
# Final absolute errors for the two variational parameters were 1.0469 & 1.0233
#
# Did 25 steps of inference.
# Final absolute errors for the two variational parameters were 1.0455 & 1.0211
#
# Did 26 steps of inference.
# Final absolute errors for the two variational parameters were 1.0444 & 1.0192
#
# Did 27 steps of inference.
# Final absolute errors for the two variational parameters were 1.0431 & 1.0170
#
# Did 28 steps of inference.
# Final absolute errors for the two variational parameters were 1.0419 & 1.0148
#
# Did 29 steps of inference.
# Final absolute errors for the two variational parameters were 1.0413 & 1.0133
#
# Did 30 steps of inference.
# Final absolute errors for the two variational parameters were 1.0407 & 1.0117
# Did 31 steps of inference.
# Final absolute errors for the two variational parameters were 1.0410 & 1.0114
#
# Did 32 steps of inference.
# Final absolute errors for the two variational parameters were 1.0418 & 1.0116
#
# Did 33 steps of inference.
# Final absolute errors for the two variational parameters were 1.0425 & 1.0115
#
# Did 34 steps of inference.
# Final absolute errors for the two variational parameters were 1.0430 & 1.0113
#
# Did 35 steps of inference.
# Final absolute errors for the two variational parameters were 1.0433 & 1.0106
#
# Did 36 steps of inference.
# Final absolute errors for the two variational parameters were 1.0422 & 1.0089
#
# Did 37 steps of inference.
# Final absolute errors for the two variational parameters were 1.0424 & 1.0089
#
# Did 38 steps of inference.
# Final absolute errors for the two variational parameters were 1.0422 & 1.0086
#
# Did 39 steps of inference.
# Final absolute errors for the two variational parameters were 1.0428 & 1.0090
#
# Did 40 steps of inference.
# Final absolute errors for the two variational parameters were 1.0426 & 1.0087
#
# Did 41 steps of inference.
# Final absolute errors for the two variational parameters were 1.0428 & 1.0087
#
# Did 42 steps of inference.
# Final absolute errors for the two variational parameters were 1.0427 & 1.0083
#
# Did 43 steps of inference.
# Final absolute errors for the two variational parameters were 1.0432 & 1.0085
#
# Did 44 steps of inference.
# Final absolute errors for the two variational parameters were 1.0432 & 1.0083
#
# Did 45 steps of inference.
# Final absolute errors for the two variational parameters were 1.0441 & 1.0090
#
# Did 46 steps of inference.
# Final absolute errors for the two variational parameters were 1.0453 & 1.0099
#
# Did 47 steps of inference.
# Final absolute errors for the two variational parameters were 1.0463 & 1.0107
#
# Did 48 steps of inference.
# Final absolute errors for the two variational parameters were 1.0467 & 1.0107
#
# Did 49 steps of inference.
# Final absolute errors for the two variational parameters were 1.0444 & 1.0090
#
# Did 50 steps of inference.
# Final absolute errors for the two variational parameters were 1.0430 & 1.0086
#
# Did 51 steps of inference.
# Final absolute errors for the two variational parameters were 1.0413 & 1.0076
#
# Did 52 steps of inference.
# Final absolute errors for the two variational parameters were 1.0399 & 1.0069
#
# Did 53 steps of inference.
# Final absolute errors for the two variational parameters were 1.0386 & 1.0062
#
# Did 54 steps of inference.
# Final absolute errors for the two variational parameters were 1.0367 & 1.0047
#
# Did 55 steps of inference.
# Final absolute errors for the two variational parameters were 1.0339 & 1.0024
#
# Did 56 steps of inference.
# Final absolute errors for the two variational parameters were 1.0312 & 1.0001
#
# Did 57 steps of inference.
# Final absolute errors for the two variational parameters were 1.0292 & 0.9984
#
# Did 58 steps of inference.
# Final absolute errors for the two variational parameters were 1.0270 & 0.9965
#
# Did 59 steps of inference.
# Final absolute errors for the two variational parameters were 1.0245 & 0.9942
#
# Did 60 steps of inference.
# Final absolute errors for the two variational parameters were 1.0226 & 0.9926
#
# Did 61 steps of inference.
# Final absolute errors for the two variational parameters were 1.0206 & 0.9909
#
# Did 62 steps of inference.
# Final absolute errors for the two variational parameters were 1.0190 & 0.9894
#
# Did 63 steps of inference.
# Final absolute errors for the two variational parameters were 1.0176 & 0.9880
#
# Did 64 steps of inference.
# Final absolute errors for the two variational parameters were 1.0164 & 0.9868
#
# Did 65 steps of inference.
# Final absolute errors for the two variational parameters were 1.0160 & 0.9866
#
# Did 66 steps of inference.
# Final absolute errors for the two variational parameters were 1.0152 & 0.9859
#
# Did 67 steps of inference.
# Final absolute errors for the two variational parameters were 1.0148 & 0.9857
#
# Did 68 steps of inference.
# Final absolute errors for the two variational parameters were 1.0134 & 0.9845
#
# Did 69 steps of inference.
# Final absolute errors for the two variational parameters were 1.0123 & 0.9836
#
# Did 70 steps of inference.
# Final absolute errors for the two variational parameters were 1.0118 & 0.9835
#
# Did 71 steps of inference.
# Final absolute errors for the two variational parameters were 1.0111 & 0.9830
#
# Did 72 steps of inference.
# Final absolute errors for the two variational parameters were 1.0104 & 0.9823
#
# Did 73 steps of inference.
# Final absolute errors for the two variational parameters were 1.0086 & 0.9807
#
# Did 74 steps of inference.
# Final absolute errors for the two variational parameters were 1.0065 & 0.9787
#
# Did 75 steps of inference.
# Final absolute errors for the two variational parameters were 1.0051 & 0.9776
#
# Did 76 steps of inference.
# Final absolute errors for the two variational parameters were 1.0035 & 0.9761
#
# Did 77 steps of inference.
# Final absolute errors for the two variational parameters were 1.0024 & 0.9753
#
# Did 78 steps of inference.
# Final absolute errors for the two variational parameters were 1.0015 & 0.9745
#
# Did 79 steps of inference.
# Final absolute errors for the two variational parameters were 1.0003 & 0.9733
#
# Did 80 steps of inference.
# Final absolute errors for the two variational parameters were 0.9991 & 0.9721
#
# Did 81 steps of inference.
# Final absolute errors for the two variational parameters were 0.9971 & 0.9701
#
# Did 82 steps of inference.
# Final absolute errors for the two variational parameters were 0.9947 & 0.9675
#
# Did 83 steps of inference.
# Final absolute errors for the two variational parameters were 0.9917 & 0.9644
#
# Did 84 steps of inference.
# Final absolute errors for the two variational parameters were 0.9888 & 0.9615
#
# Did 85 steps of inference.
# Final absolute errors for the two variational parameters were 0.9866 & 0.9591
#
# Did 86 steps of inference.
# Final absolute errors for the two variational parameters were 0.9844 & 0.9566
#
# Did 87 steps of inference.
# Final absolute errors for the two variational parameters were 0.9823 & 0.9543
#
# Did 88 steps of inference.
# Final absolute errors for the two variational parameters were 0.9806 & 0.9522
#
# Did 89 steps of inference.
# Final absolute errors for the two variational parameters were 0.9787 & 0.9499
#
# Did 90 steps of inference.
# Final absolute errors for the two variational parameters were 0.9770 & 0.9477
#
# Did 91 steps of inference.
# Final absolute errors for the two variational parameters were 0.9745 & 0.9448
#
# Did 92 steps of inference.
# Final absolute errors for the two variational parameters were 0.9725 & 0.9424
#
# Did 93 steps of inference.
# Final absolute errors for the two variational parameters were 0.9707 & 0.9401
#
# Did 94 steps of inference.
# Final absolute errors for the two variational parameters were 0.9692 & 0.9382
#
# Did 95 steps of inference.
# Final absolute errors for the two variational parameters were 0.9678 & 0.9362
#
# Did 96 steps of inference.
# Final absolute errors for the two variational parameters were 0.9668 & 0.9348
#
# Did 97 steps of inference.
# Final absolute errors for the two variational parameters were 0.9666 & 0.9345
#
# Did 98 steps of inference.
# Final absolute errors for the two variational parameters were 0.9655 & 0.9333
#
# Did 99 steps of inference.
# Final absolute errors for the two variational parameters were 0.9649 & 0.9326
# .
# Did 100 steps of inference.
# Final absolute errors for the two variational parameters were 0.9648 & 0.9326
#
# Did 101 steps of inference.
# Final absolute errors for the two variational parameters were 0.9642 & 0.9320
#
# Did 102 steps of inference.
# Final absolute errors for the two variational parameters were 0.9625 & 0.9304
#
# Did 103 steps of inference.
# Final absolute errors for the two variational parameters were 0.9609 & 0.9290
#
# Did 104 steps of inference.
# Final absolute errors for the two variational parameters were 0.9600 & 0.9282
#
# Did 105 steps of inference.
# Final absolute errors for the two variational parameters were 0.9591 & 0.9274
#
# Did 106 steps of inference.
# Final absolute errors for the two variational parameters were 0.9586 & 0.9269
#
# Did 107 steps of inference.
# Final absolute errors for the two variational parameters were 0.9576 & 0.9259
#
# Did 108 steps of inference.
# Final absolute errors for the two variational parameters were 0.9562 & 0.9244
#
# Did 109 steps of inference.
# Final absolute errors for the two variational parameters were 0.9549 & 0.9229
#
# Did 110 steps of inference.
# Final absolute errors for the two variational parameters were 0.9534 & 0.9211
#
# Did 111 steps of inference.
# Final absolute errors for the two variational parameters were 0.9522 & 0.9195
#
# Did 112 steps of inference.
# Final absolute errors for the two variational parameters were 0.9507 & 0.9177
#
# Did 113 steps of inference.
# Final absolute errors for the two variational parameters were 0.9492 & 0.9157
#
# Did 114 steps of inference.
# Final absolute errors for the two variational parameters were 0.9480 & 0.9140
#
# Did 115 steps of inference.
# Final absolute errors for the two variational parameters were 0.9464 & 0.9119
#
# Did 116 steps of inference.
# Final absolute errors for the two variational parameters were 0.9454 & 0.9104
#
# Did 117 steps of inference.
# Final absolute errors for the two variational parameters were 0.9443 & 0.9088
#
# Did 118 steps of inference.
# Final absolute errors for the two variational parameters were 0.9430 & 0.9070
#
# Did 119 steps of inference.
# Final absolute errors for the two variational parameters were 0.9415 & 0.9049
#
# Did 120 steps of inference.
# Final absolute errors for the two variational parameters were 0.9402 & 0.9028
#
# Did 121 steps of inference.
# Final absolute errors for the two variational parameters were 0.9392 & 0.9012
#
# Did 122 steps of inference.
# Final absolute errors for the two variational parameters were 0.9381 & 0.8993
#
# Did 123 steps of inference.
# Final absolute errors for the two variational parameters were 0.9375 & 0.8981
#
# Did 124 steps of inference.
# Final absolute errors for the two variational parameters were 0.9374 & 0.8975
#
# Did 125 steps of inference.
# Final absolute errors for the two variational parameters were 0.9365 & 0.8962
#
# Did 126 steps of inference.
# Final absolute errors for the two variational parameters were 0.9356 & 0.8947
#
# Did 127 steps of inference.
# Final absolute errors for the two variational parameters were 0.9350 & 0.8936
#
# Did 128 steps of inference.
# Final absolute errors for the two variational parameters were 0.9344 & 0.8924
#
# Did 129 steps of inference.
# Final absolute errors for the two variational parameters were 0.9335 & 0.8909
#
# Did 130 steps of inference.
# Final absolute errors for the two variational parameters were 0.9325 & 0.8892
#
# Did 131 steps of inference.
# Final absolute errors for the two variational parameters were 0.9309 & 0.8869
# Did 132 steps of inference.
# Final absolute errors for the two variational parameters were 0.9297 & 0.8851
#
# Did 133 steps of inference.
# Final absolute errors for the two variational parameters were 0.9293 & 0.8842
#
# Did 134 steps of inference.
# Final absolute errors for the two variational parameters were 0.9294 & 0.8840
#
# Did 135 steps of inference.
# Final absolute errors for the two variational parameters were 0.9294 & 0.8837
#
# Did 136 steps of inference.
# Final absolute errors for the two variational parameters were 0.9301 & 0.8842
#
# Did 137 steps of inference.
# Final absolute errors for the two variational parameters were 0.9307 & 0.8846
#
# Did 138 steps of inference.
# Final absolute errors for the two variational parameters were 0.9313 & 0.8849
#
# Did 139 steps of inference.
# Final absolute errors for the two variational parameters were 0.9321 & 0.8853
#
# Did 140 steps of inference.
# Final absolute errors for the two variational parameters were 0.9330 & 0.8858
#
# Did 141 steps of inference.
# Final absolute errors for the two variational parameters were 0.9335 & 0.8858
#
# Did 142 steps of inference.
# Final absolute errors for the two variational parameters were 0.9339 & 0.8857
#
# Did 143 steps of inference.
# Final absolute errors for the two variational parameters were 0.9343 & 0.8855
#
# Did 144 steps of inference.
# Final absolute errors for the two variational parameters were 0.9349 & 0.8856
#
# Did 145 steps of inference.
# Final absolute errors for the two variational parameters were 0.9360 & 0.8861
#
# Did 146 steps of inference.
# Final absolute errors for the two variational parameters were 0.9369 & 0.8864
#
# Did 147 steps of inference.
# Final absolute errors for the two variational parameters were 0.9366 & 0.8857
#
# Did 148 steps of inference.
# Final absolute errors for the two variational parameters were 0.9365 & 0.8852
#
# Did 149 steps of inference.
# Final absolute errors for the two variational parameters were 0.9367 & 0.8849
#
# Did 150 steps of inference.
# Final absolute errors for the two variational parameters were 0.9366 & 0.8843
#
# Did 151 steps of inference.
# Final absolute errors for the two variational parameters were 0.9369 & 0.8840
#
# Did 152 steps of inference.
# Final absolute errors for the two variational parameters were 0.9368 & 0.8834
#
# Did 153 steps of inference.
# Final absolute errors for the two variational parameters were 0.9369 & 0.8828
#
# Did 154 steps of inference.
# Final absolute errors for the two variational parameters were 0.9373 & 0.8827
#
# Did 155 steps of inference.
# Final absolute errors for the two variational parameters were 0.9375 & 0.8822
#
# Did 156 steps of inference.
# Final absolute errors for the two variational parameters were 0.9380 & 0.8822
#
# Did 157 steps of inference.
# Final absolute errors for the two variational parameters were 0.9386 & 0.8822
#
# Did 158 steps of inference.
# Final absolute errors for the two variational parameters were 0.9390 & 0.8819
#
# Did 159 steps of inference.
# Final absolute errors for the two variational parameters were 0.9390 & 0.8812
#
# Did 160 steps of inference.
# Final absolute errors for the two variational parameters were 0.9390 & 0.8804
#
# Did 161 steps of inference.
# Final absolute errors for the two variational parameters were 0.9388 & 0.8794
#
# Did 162 steps of inference.
# Final absolute errors for the two variational parameters were 0.9393 & 0.8794
#
# Did 163 steps of inference.
# Final absolute errors for the two variational parameters were 0.9391 & 0.8787
#
# Did 164 steps of inference.
# Final absolute errors for the two variational parameters were 0.9384 & 0.8775
#
# Did 165 steps of inference.
# Final absolute errors for the two variational parameters were 0.9383 & 0.8770
#
# Did 166 steps of inference.
# Final absolute errors for the two variational parameters were 0.9387 & 0.8771
#
# Did 167 steps of inference.
# Final absolute errors for the two variational parameters were 0.9395 & 0.8776
#
# Did 168 steps of inference.
# Final absolute errors for the two variational parameters were 0.9403 & 0.8781
#
# Did 169 steps of inference.
# Final absolute errors for the two variational parameters were 0.9410 & 0.8784
#
# Did 170 steps of inference.
# Final absolute errors for the two variational parameters were 0.9415 & 0.8784
#
# Did 171 steps of inference.
# Final absolute errors for the two variational parameters were 0.9415 & 0.8778
#
# Did 172 steps of inference.
# Final absolute errors for the two variational parameters were 0.9414 & 0.8771
#
# Did 173 steps of inference.
# Final absolute errors for the two variational parameters were 0.9405 & 0.8756
#
# Did 174 steps of inference.
# Final absolute errors for the two variational parameters were 0.9391 & 0.8738
#
# Did 175 steps of inference.
# Final absolute errors for the two variational parameters were 0.9366 & 0.8710
#
# Did 176 steps of inference.
# Final absolute errors for the two variational parameters were 0.9349 & 0.8692
#
# Did 177 steps of inference.
# Final absolute errors for the two variational parameters were 0.9327 & 0.8670
#
# Did 178 steps of inference.
# Final absolute errors for the two variational parameters were 0.9312 & 0.8654
#
# Did 179 steps of inference.
# Final absolute errors for the two variational parameters were 0.9298 & 0.8639
#
# Did 180 steps of inference.
# Final absolute errors for the two variational parameters were 0.9286 & 0.8625
#
# Did 181 steps of inference.
# Final absolute errors for the two variational parameters were 0.9275 & 0.8610
#
# Did 182 steps of inference.
# Final absolute errors for the two variational parameters were 0.9255 & 0.8588
#
# Did 183 steps of inference.
# Final absolute errors for the two variational parameters were 0.9242 & 0.8575
#
# Did 184 steps of inference.
# Final absolute errors for the two variational parameters were 0.9222 & 0.8554
#
# Did 185 steps of inference.
# Final absolute errors for the two variational parameters were 0.9210 & 0.8543
#
# Did 186 steps of inference.
# Final absolute errors for the two variational parameters were 0.9201 & 0.8533
#
# Did 187 steps of inference.
# Final absolute errors for the two variational parameters were 0.9187 & 0.8519
#
# Did 188 steps of inference.
# Final absolute errors for the two variational parameters were 0.9167 & 0.8499
#
# Did 189 steps of inference.
# Final absolute errors for the two variational parameters were 0.9151 & 0.8482
#
# Did 190 steps of inference.
# Final absolute errors for the two variational parameters were 0.9130 & 0.8460
#
# Did 191 steps of inference.
# Final absolute errors for the two variational parameters were 0.9115 & 0.8445
#
# Did 192 steps of inference.
# Final absolute errors for the two variational parameters were 0.9100 & 0.8428
#
# Did 193 steps of inference.
# Final absolute errors for the two variational parameters were 0.9082 & 0.8408
#
# Did 194 steps of inference.
# Final absolute errors for the two variational parameters were 0.9074 & 0.8402
#
# Did 195 steps of inference.
# Final absolute errors for the two variational parameters were 0.9068 & 0.8398
#
# Did 196 steps of inference.
# Final absolute errors for the two variational parameters were 0.9064 & 0.8393
#
# Did 197 steps of inference.
# Final absolute errors for the two variational parameters were 0.9051 & 0.8381
#
# Did 198 steps of inference.
# Final absolute errors for the two variational parameters were 0.9043 & 0.8375
#
# Did 199 steps of inference.
# Final absolute errors for the two variational parameters were 0.9037 & 0.8369
# .
# Did 200 steps of inference.
# Final absolute errors for the two variational parameters were 0.9025 & 0.8356
#
# Did 201 steps of inference.
# Final absolute errors for the two variational parameters were 0.9018 & 0.8351
#
# Did 202 steps of inference.
# Final absolute errors for the two variational parameters were 0.9014 & 0.8346
#
# Did 203 steps of inference.
# Final absolute errors for the two variational parameters were 0.9004 & 0.8336
#
# Did 204 steps of inference.
# Final absolute errors for the two variational parameters were 0.8998 & 0.8328
#
# Did 205 steps of inference.
# Final absolute errors for the two variational parameters were 0.8993 & 0.8322
#
# Did 206 steps of inference.
# Final absolute errors for the two variational parameters were 0.8991 & 0.8317
#
# Did 207 steps of inference.
# Final absolute errors for the two variational parameters were 0.8993 & 0.8317
#
# Did 208 steps of inference.
# Final absolute errors for the two variational parameters were 0.8989 & 0.8310
#
# Did 209 steps of inference.
# Final absolute errors for the two variational parameters were 0.8983 & 0.8302
#
# Did 210 steps of inference.
# Final absolute errors for the two variational parameters were 0.8987 & 0.8307
#
# Did 211 steps of inference.
# Final absolute errors for the two variational parameters were 0.8992 & 0.8312
#
# Did 212 steps of inference.
# Final absolute errors for the two variational parameters were 0.8994 & 0.8313
#
# Did 213 steps of inference.
# Final absolute errors for the two variational parameters were 0.9002 & 0.8321
#
# Did 214 steps of inference.
# Final absolute errors for the two variational parameters were 0.9004 & 0.8323
#
# Did 215 steps of inference.
# Final absolute errors for the two variational parameters were 0.9002 & 0.8319
#
# Did 216 steps of inference.
# Final absolute errors for the two variational parameters were 0.9002 & 0.8318
#
# Did 217 steps of inference.
# Final absolute errors for the two variational parameters were 0.9007 & 0.8321
#
# Did 218 steps of inference.
# Final absolute errors for the two variational parameters were 0.9012 & 0.8324
#
# Did 219 steps of inference.
# Final absolute errors for the two variational parameters were 0.9024 & 0.8336
#
# Did 220 steps of inference.
# Final absolute errors for the two variational parameters were 0.9035 & 0.8345
#
# Did 221 steps of inference.
# Final absolute errors for the two variational parameters were 0.9046 & 0.8355
#
# Did 222 steps of inference.
# Final absolute errors for the two variational parameters were 0.9058 & 0.8364
# Did 223 steps of inference.
# Final absolute errors for the two variational parameters were 0.9076 & 0.8381
#
# Did 224 steps of inference.
# Final absolute errors for the two variational parameters were 0.9094 & 0.8399
#
# Did 225 steps of inference.
# Final absolute errors for the two variational parameters were 0.9108 & 0.8410
#
# Did 226 steps of inference.
# Final absolute errors for the two variational parameters were 0.9124 & 0.8424
#
# Did 227 steps of inference.
# Final absolute errors for the two variational parameters were 0.9138 & 0.8435
#
# Did 228 steps of inference.
# Final absolute errors for the two variational parameters were 0.9158 & 0.8455
#
# Did 229 steps of inference.
# Final absolute errors for the two variational parameters were 0.9171 & 0.8467
#
# Did 230 steps of inference.
# Final absolute errors for the two variational parameters were 0.9188 & 0.8486
#
# Did 231 steps of inference.
# Final absolute errors for the two variational parameters were 0.9203 & 0.8501
#
# Did 232 steps of inference.
# Final absolute errors for the two variational parameters were 0.9222 & 0.8521
#
# Did 233 steps of inference.
# Final absolute errors for the two variational parameters were 0.9238 & 0.8537
#
# Did 234 steps of inference.
# Final absolute errors for the two variational parameters were 0.9252 & 0.8550
#
# Did 235 steps of inference.
# Final absolute errors for the two variational parameters were 0.9264 & 0.8560
#
# Did 236 steps of inference.
# Final absolute errors for the two variational parameters were 0.9273 & 0.8567
#
# Did 237 steps of inference.
# Final absolute errors for the two variational parameters were 0.9282 & 0.8572
#
# Did 238 steps of inference.
# Final absolute errors for the two variational parameters were 0.9288 & 0.8574
#
# Did 239 steps of inference.
# Final absolute errors for the two variational parameters were 0.9298 & 0.8580
#
# Did 240 steps of inference.
# Final absolute errors for the two variational parameters were 0.9312 & 0.8592
#
# Did 241 steps of inference.
# Final absolute errors for the two variational parameters were 0.9320 & 0.8596
#
# Did 242 steps of inference.
# Final absolute errors for the two variational parameters were 0.9324 & 0.8597
#
# Did 243 steps of inference.
# Final absolute errors for the two variational parameters were 0.9339 & 0.8615
#
# Did 244 steps of inference.
# Final absolute errors for the two variational parameters were 0.9353 & 0.8631
#
# Did 245 steps of inference.
# Final absolute errors for the two variational parameters were 0.9367 & 0.8645
#
# Did 246 steps of inference.
# Final absolute errors for the two variational parameters were 0.9382 & 0.8660
#
# Did 247 steps of inference.
# Final absolute errors for the two variational parameters were 0.9394 & 0.8672
#
# Did 248 steps of inference.
# Final absolute errors for the two variational parameters were 0.9408 & 0.8683
#
# Did 249 steps of inference.
# Final absolute errors for the two variational parameters were 0.9419 & 0.8691
#
# Did 250 steps of inference.
# Final absolute errors for the two variational parameters were 0.9417 & 0.8689
#
# Did 251 steps of inference.
# Final absolute errors for the two variational parameters were 0.9424 & 0.8701
#
# Did 252 steps of inference.
# Final absolute errors for the two variational parameters were 0.9432 & 0.8712
#
# Did 253 steps of inference.
# Final absolute errors for the two variational parameters were 0.9431 & 0.8715
#
# Did 254 steps of inference.
# Final absolute errors for the two variational parameters were 0.9437 & 0.8725
#
# Did 255 steps of inference.
# Final absolute errors for the two variational parameters were 0.9447 & 0.8739
#
# Did 256 steps of inference.
# Final absolute errors for the two variational parameters were 0.9459 & 0.8754
#
# Did 257 steps of inference.
# Final absolute errors for the two variational parameters were 0.9463 & 0.8762
#
# Did 258 steps of inference.
# Final absolute errors for the two variational parameters were 0.9477 & 0.8783
#
# Did 259 steps of inference.
# Final absolute errors for the two variational parameters were 0.9490 & 0.8803
#
# Did 260 steps of inference.
# Final absolute errors for the two variational parameters were 0.9490 & 0.8811
#
# Did 261 steps of inference.
# Final absolute errors for the two variational parameters were 0.9493 & 0.8821
#
# Did 262 steps of inference.
# Final absolute errors for the two variational parameters were 0.9503 & 0.8842
#
# Did 263 steps of inference.
# Final absolute errors for the two variational parameters were 0.9514 & 0.8860
#
# Did 264 steps of inference.
# Final absolute errors for the two variational parameters were 0.9530 & 0.8885
#
# Did 265 steps of inference.
# Final absolute errors for the two variational parameters were 0.9542 & 0.8905
#
# Did 266 steps of inference.
# Final absolute errors for the two variational parameters were 0.9558 & 0.8928
#
# Did 267 steps of inference.
# Final absolute errors for the two variational parameters were 0.9561 & 0.8940
#
# Did 268 steps of inference.
# Final absolute errors for the two variational parameters were 0.9560 & 0.8947
#
# Did 269 steps of inference.
# Final absolute errors for the two variational parameters were 0.9556 & 0.8949
#
# Did 270 steps of inference.
# Final absolute errors for the two variational parameters were 0.9546 & 0.8945
#
# Did 271 steps of inference.
# Final absolute errors for the two variational parameters were 0.9542 & 0.8947
#
# Did 272 steps of inference.
# Final absolute errors for the two variational parameters were 0.9539 & 0.8950
#
# Did 273 steps of inference.
# Final absolute errors for the two variational parameters were 0.9540 & 0.8954
#
# Did 274 steps of inference.
# Final absolute errors for the two variational parameters were 0.9536 & 0.8954
#
# Did 275 steps of inference.
# Final absolute errors for the two variational parameters were 0.9532 & 0.8952
#
# Did 276 steps of inference.
# Final absolute errors for the two variational parameters were 0.9533 & 0.8954
#
# Did 277 steps of inference.
# Final absolute errors for the two variational parameters were 0.9536 & 0.8958
#
# Did 278 steps of inference.
# Final absolute errors for the two variational parameters were 0.9548 & 0.8976
#
# Did 279 steps of inference.
# Final absolute errors for the two variational parameters were 0.9560 & 0.8991
#
# Did 280 steps of inference.
# Final absolute errors for the two variational parameters were 0.9563 & 0.8999
#
# Did 281 steps of inference.
# Final absolute errors for the two variational parameters were 0.9568 & 0.9008
#
# Did 282 steps of inference.
# Final absolute errors for the two variational parameters were 0.9582 & 0.9027
#
# Did 283 steps of inference.
# Final absolute errors for the two variational parameters were 0.9589 & 0.9039
#
# Did 284 steps of inference.
# Final absolute errors for the two variational parameters were 0.9598 & 0.9051
#
# Did 285 steps of inference.
# Final absolute errors for the two variational parameters were 0.9606 & 0.9062
#
# Did 286 steps of inference.
# Final absolute errors for the two variational parameters were 0.9614 & 0.9071
#
# Did 287 steps of inference.
# Final absolute errors for the two variational parameters were 0.9621 & 0.9078
#
# Did 288 steps of inference.
# Final absolute errors for the two variational parameters were 0.9623 & 0.9080
#
# Did 289 steps of inference.
# Final absolute errors for the two variational parameters were 0.9630 & 0.9089
#
# Did 290 steps of inference.
# ...
#
# Did 590 steps of inference.
# Final absolute errors for the two variational parameters were 0.8970 & 0.8478
#
# Did 591 steps of inference.
# Final absolute errors for the two variational parameters were 0.8968 & 0.8480
#
# Did 592 steps of inference.
# Final absolute errors for the two variational parameters were 0.8969 & 0.8483
#
# Did 593 steps of inference.
# Final absolute errors for the two variational parameters were 0.8970 & 0.8487
#
# Did 594 steps of inference.
# Final absolute errors for the two variational parameters were 0.8964 & 0.8483
#
# Did 595 steps of inference.
# Final absolute errors for the two variational parameters were 0.8963 & 0.8484
#
# Did 596 steps of inference.
# Final absolute errors for the two variational parameters were 0.8964 & 0.8486
#
# Did 597 steps of inference.
# Final absolute errors for the two variational parameters were 0.8974 & 0.8500
#
# Did 598 steps of inference.
# Final absolute errors for the two variational parameters were 0.8978 & 0.8509
#
# Did 599 steps of inference.
# Final absolute errors for the two variational parameters were 0.8985 & 0.8520
# .
# Did 600 steps of inference.
# Final absolute errors for the two variational parameters were 0.8998 & 0.8537
#
# Did 601 steps of inference.
# Final absolute errors for the two variational parameters were 0.9017 & 0.8560
#
# Did 602 steps of inference.
# Final absolute errors for the two variational parameters were 0.9035 & 0.8581
#
# Did 603 steps of inference.
# Final absolute errors for the two variational parameters were 0.9054 & 0.8604
#
# Did 604 steps of inference.
# Final absolute errors for the two variational parameters were 0.9080 & 0.8634
#
# Did 605 steps of inference.
# Final absolute errors for the two variational parameters were 0.9112 & 0.8672
#
# Did 606 steps of inference.
# Final absolute errors for the two variational parameters were 0.9136 & 0.8702
#
# Did 607 steps of inference.
# Final absolute errors for the two variational parameters were 0.9163 & 0.8733
#
# Did 608 steps of inference.
# Final absolute errors for the two variational parameters were 0.9191 & 0.8765
#
# Did 609 steps of inference.
# Final absolute errors for the two variational parameters were 0.9223 & 0.8802
#
# Did 610 steps of inference.
# Final absolute errors for the two variational parameters were 0.9252 & 0.8834
#
# Did 611 steps of inference.
# Final absolute errors for the two variational parameters were 0.9286 & 0.8873
#
# Did 612 steps of inference.
# Final absolute errors for the two variational parameters were 0.9323 & 0.8915
#
# Did 613 steps of inference.
# Final absolute errors for the two variational parameters were 0.9365 & 0.8964
#
# Did 614 steps of inference.
# Final absolute errors for the two variational parameters were 0.9400 & 0.9004
#
# Did 615 steps of inference.
# Final absolute errors for the two variational parameters were 0.9437 & 0.9045
#
# Did 616 steps of inference.
# Final absolute errors for the two variational parameters were 0.9479 & 0.9095
#
# Did 617 steps of inference.
# Final absolute errors for the two variational parameters were 0.9524 & 0.9147
#
# Did 618 steps of inference.
# Final absolute errors for the two variational parameters were 0.9554 & 0.9186
#
# Did 619 steps of inference.
# Final absolute errors for the two variational parameters were 0.9581 & 0.9221
#
# Did 620 steps of inference.
# Final absolute errors for the two variational parameters were 0.9610 & 0.9256
#
# Did 621 steps of inference.
# Final absolute errors for the two variational parameters were 0.9639 & 0.9291
#
# Did 622 steps of inference.
# Final absolute errors for the two variational parameters were 0.9648 & 0.9311
#
# Did 623 steps of inference.
# Final absolute errors for the two variational parameters were 0.9662 & 0.9337
#
# Did 624 steps of inference.
# Final absolute errors for the two variational parameters were 0.9678 & 0.9363
#
# Did 625 steps of inference.
# Final absolute errors for the two variational parameters were 0.9700 & 0.9397
#
# Did 626 steps of inference.
# Final absolute errors for the two variational parameters were 0.9726 & 0.9435
#
# Did 627 steps of inference.
# Final absolute errors for the two variational parameters were 0.9750 & 0.9469
#
# Did 628 steps of inference.
# Final absolute errors for the two variational parameters were 0.9771 & 0.9498
#
# Did 629 steps of inference.
# Final absolute errors for the two variational parameters were 0.9784 & 0.9520
#
# Did 630 steps of inference.
# Final absolute errors for the two variational parameters were 0.9800 & 0.9542
#
# Did 631 steps of inference.
# Final absolute errors for the two variational parameters were 0.9806 & 0.9555
#
# Did 632 steps of inference.
# Final absolute errors for the two variational parameters were 0.9812 & 0.9567
#
# Did 633 steps of inference.
# Final absolute errors for the two variational parameters were 0.9821 & 0.9581
#
# Did 634 steps of inference.
# Final absolute errors for the two variational parameters were 0.9825 & 0.9589
#
# Did 635 steps of inference.
# Final absolute errors for the two variational parameters were 0.9833 & 0.9600
#
# Did 636 steps of inference.
# Final absolute errors for the two variational parameters were 0.9822 & 0.9598
#
# Did 637 steps of inference.
# Final absolute errors for the two variational parameters were 0.9811 & 0.9594
#
# Did 638 steps of inference.
# Final absolute errors for the two variational parameters were 0.9804 & 0.9594
#
# Did 639 steps of inference.
# Final absolute errors for the two variational parameters were 0.9801 & 0.9597
#
# Did 640 steps of inference.
# Final absolute errors for the two variational parameters were 0.9799 & 0.9599
#
# Did 641 steps of inference.
# Final absolute errors for the two variational parameters were 0.9803 & 0.9607
#
# Did 642 steps of inference.
# Final absolute errors for the two variational parameters were 0.9800 & 0.9608
#
# Did 643 steps of inference.
# Final absolute errors for the two variational parameters were 0.9786 & 0.9600
#
# Did 644 steps of inference.
# Final absolute errors for the two variational parameters were 0.9775 & 0.9594
#
# Did 645 steps of inference.
# Final absolute errors for the two variational parameters were 0.9757 & 0.9581
#
# Did 646 steps of inference.
# Final absolute errors for the two variational parameters were 0.9740 & 0.9568
#
# Did 647 steps of inference.
# Final absolute errors for the two variational parameters were 0.9725 & 0.9556
#
# Did 648 steps of inference.
# Final absolute errors for the two variational parameters were 0.9716 & 0.9549
#
# Did 649 steps of inference.
# Final absolute errors for the two variational parameters were 0.9705 & 0.9540
#
# Did 650 steps of inference.
# Final absolute errors for the two variational parameters were 0.9701 & 0.9537
#
# Did 651 steps of inference.
# Final absolute errors for the two variational parameters were 0.9702 & 0.9541
#
# Did 652 steps of inference.
# Final absolute errors for the two variational parameters were 0.9702 & 0.9541
#
# Did 653 steps of inference.
# Final absolute errors for the two variational parameters were 0.9696 & 0.9537
#
# Did 654 steps of inference.
# Final absolute errors for the two variational parameters were 0.9692 & 0.9533
#
# Did 655 steps of inference.
# Final absolute errors for the two variational parameters were 0.9690 & 0.9530
#
# Did 656 steps of inference.
# Final absolute errors for the two variational parameters were 0.9685 & 0.9523
#
# Did 657 steps of inference.
# Final absolute errors for the two variational parameters were 0.9686 & 0.9524
#
# Did 658 steps of inference.
# Final absolute errors for the two variational parameters were 0.9681 & 0.9518
#
# Did 659 steps of inference.
# Final absolute errors for the two variational parameters were 0.9663 & 0.9503
#
# Did 660 steps of inference.
# Final absolute errors for the two variational parameters were 0.9653 & 0.9496
#
# Did 661 steps of inference.
# Final absolute errors for the two variational parameters were 0.9646 & 0.9491
#
# Did 662 steps of inference.
# Final absolute errors for the two variational parameters were 0.9644 & 0.9491
#
# Did 663 steps of inference.
# Final absolute errors for the two variational parameters were 0.9640 & 0.9488
#
# Did 664 steps of inference.
# Final absolute errors for the two variational parameters were 0.9631 & 0.9480
#
# Did 665 steps of inference.
# Final absolute errors for the two variational parameters were 0.9627 & 0.9476
#
# Did 666 steps of inference.
# Final absolute errors for the two variational parameters were 0.9621 & 0.9469
#
# Did 667 steps of inference.
# Final absolute errors for the two variational parameters were 0.9618 & 0.9466
#
# Did 668 steps of inference.
# Final absolute errors for the two variational parameters were 0.9610 & 0.9457
#
# Did 669 steps of inference.
# Final absolute errors for the two variational parameters were 0.9606 & 0.9453
#
# Did 670 steps of inference.
# Final absolute errors for the two variational parameters were 0.9605 & 0.9450
#
# Did 671 steps of inference.
# Final absolute errors for the two variational parameters were 0.9592 & 0.9438
#
# Did 672 steps of inference.
# Final absolute errors for the two variational parameters were 0.9582 & 0.9429
#
# Did 673 steps of inference.
# Final absolute errors for the two variational parameters were 0.9571 & 0.9418
# Did 674 steps of inference.
# Final absolute errors for the two variational parameters were 0.9564 & 0.9409
#
# Did 675 steps of inference.
# Final absolute errors for the two variational parameters were 0.9548 & 0.9394
#
# Did 676 steps of inference.
# Final absolute errors for the two variational parameters were 0.9528 & 0.9374
#
# Did 677 steps of inference.
# Final absolute errors for the two variational parameters were 0.9503 & 0.9349
#
# Did 678 steps of inference.
# Final absolute errors for the two variational parameters were 0.9481 & 0.9327
#
# Did 679 steps of inference.
# Final absolute errors for the two variational parameters were 0.9464 & 0.9308
#
# Did 680 steps of inference.
# Final absolute errors for the two variational parameters were 0.9445 & 0.9288
#
# Did 681 steps of inference.
# Final absolute errors for the two variational parameters were 0.9433 & 0.9274
#
# Did 682 steps of inference.
# Final absolute errors for the two variational parameters were 0.9413 & 0.9254
#
# Did 683 steps of inference.
# Final absolute errors for the two variational parameters were 0.9396 & 0.9236
#
# Did 684 steps of inference.
# Final absolute errors for the two variational parameters were 0.9370 & 0.9211
#
# Did 685 steps of inference.
# Final absolute errors for the two variational parameters were 0.9350 & 0.9192
#
# Did 686 steps of inference.
# Final absolute errors for the two variational parameters were 0.9330 & 0.9171
#
# Did 687 steps of inference.
# Final absolute errors for the two variational parameters were 0.9316 & 0.9157
#
# Did 688 steps of inference.
# Final absolute errors for the two variational parameters were 0.9308 & 0.9149
#
# Did 689 steps of inference.
# Final absolute errors for the two variational parameters were 0.9302 & 0.9143
#
# Did 690 steps of inference.
# Final absolute errors for the two variational parameters were 0.9291 & 0.9131
#
# Did 691 steps of inference.
# Final absolute errors for the two variational parameters were 0.9276 & 0.9115
#
# Did 692 steps of inference.
# Final absolute errors for the two variational parameters were 0.9265 & 0.9103
#
# Did 693 steps of inference.
# Final absolute errors for the two variational parameters were 0.9262 & 0.9101
#
# Did 694 steps of inference.
# Final absolute errors for the two variational parameters were 0.9260 & 0.9098
#
# Did 695 steps of inference.
# Final absolute errors for the two variational parameters were 0.9265 & 0.9107
#
# Did 696 steps of inference.
# Final absolute errors for the two variational parameters were 0.9259 & 0.9105
#
# Did 697 steps of inference.
# Final absolute errors for the two variational parameters were 0.9241 & 0.9094
#
# Did 698 steps of inference.
# Final absolute errors for the two variational parameters were 0.9226 & 0.9086
#
# Did 699 steps of inference.
# Final absolute errors for the two variational parameters were 0.9202 & 0.9070
# .
# Did 700 steps of inference.
# Final absolute errors for the two variational parameters were 0.9178 & 0.9051
#
# Did 701 steps of inference.
# Final absolute errors for the two variational parameters were 0.9151 & 0.9030
#
# Did 702 steps of inference.
# Final absolute errors for the two variational parameters were 0.9116 & 0.9002
#
# Did 703 steps of inference.
# Final absolute errors for the two variational parameters were 0.9076 & 0.8969
#
# Did 704 steps of inference.
# Final absolute errors for the two variational parameters were 0.9042 & 0.8940
#
# Did 705 steps of inference.
# Final absolute errors for the two variational parameters were 0.9001 & 0.8906
#
# Did 706 steps of inference.
# Final absolute errors for the two variational parameters were 0.8966 & 0.8877
#
# Did 707 steps of inference.
# Final absolute errors for the two variational parameters were 0.8936 & 0.8852
#
# Did 708 steps of inference.
# Final absolute errors for the two variational parameters were 0.8899 & 0.8820
#
# Did 709 steps of inference.
# Final absolute errors for the two variational parameters were 0.8867 & 0.8793
#
# Did 710 steps of inference.
# Final absolute errors for the two variational parameters were 0.8833 & 0.8763
#
# Did 711 steps of inference.
# Final absolute errors for the two variational parameters were 0.8802 & 0.8737
#
# Did 712 steps of inference.
# Final absolute errors for the two variational parameters were 0.8773 & 0.8709
#
# Did 713 steps of inference.
# Final absolute errors for the two variational parameters were 0.8749 & 0.8687
#
# Did 714 steps of inference.
# Final absolute errors for the two variational parameters were 0.8729 & 0.8668
#
# Did 715 steps of inference.
# Final absolute errors for the two variational parameters were 0.8706 & 0.8646
#
# Did 716 steps of inference.
# Final absolute errors for the two variational parameters were 0.8689 & 0.8630
#
# Did 717 steps of inference.
# Final absolute errors for the two variational parameters were 0.8673 & 0.8613
#
# Did 718 steps of inference.
# Final absolute errors for the two variational parameters were 0.8650 & 0.8591
#
# Did 719 steps of inference.
# Final absolute errors for the two variational parameters were 0.8625 & 0.8566
#
# Did 720 steps of inference.
# Final absolute errors for the two variational parameters were 0.8605 & 0.8545
#
# Did 721 steps of inference.
# Final absolute errors for the two variational parameters were 0.8585 & 0.8524
#
# Did 722 steps of inference.
# Final absolute errors for the two variational parameters were 0.8555 & 0.8495
#
# Did 723 steps of inference.
# Final absolute errors for the two variational parameters were 0.8528 & 0.8469
#
# Did 724 steps of inference.
# Final absolute errors for the two variational parameters were 0.8477 & 0.8429
#
# Did 725 steps of inference.
# Final absolute errors for the two variational parameters were 0.8421 & 0.8385
#
# Did 726 steps of inference.
# Final absolute errors for the two variational parameters were 0.8368 & 0.8343
#
# Did 727 steps of inference.
# Final absolute errors for the two variational parameters were 0.8324 & 0.8307
#
# Did 728 steps of inference.
# Final absolute errors for the two variational parameters were 0.8288 & 0.8281
#
# Did 729 steps of inference.
# Final absolute errors for the two variational parameters were 0.8244 & 0.8248
#
# Did 730 steps of inference.
# Final absolute errors for the two variational parameters were 0.8199 & 0.8212
#
# Did 731 steps of inference.
# Final absolute errors for the two variational parameters were 0.8158 & 0.8179
#
# Did 732 steps of inference.
# Final absolute errors for the two variational parameters were 0.8120 & 0.8148
#
# Did 733 steps of inference.
# Final absolute errors for the two variational parameters were 0.8090 & 0.8125
#
# Did 734 steps of inference.
# Final absolute errors for the two variational parameters were 0.8057 & 0.8098
#
# Did 735 steps of inference.
# Final absolute errors for the two variational parameters were 0.8016 & 0.8065
#
# Did 736 steps of inference.
# Final absolute errors for the two variational parameters were 0.7984 & 0.8041
#
# Did 737 steps of inference.
# Final absolute errors for the two variational parameters were 0.7959 & 0.8023
#
# Did 738 steps of inference.
# Final absolute errors for the two variational parameters were 0.7941 & 0.8013
